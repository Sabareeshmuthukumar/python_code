# %%
#1.TWO SUM
a=[1,2,3,4,5,6,7,8,9]
target=9
for i in range(len(a)):
    for j in range(i+1,len(a)):
        if a[i]+a[j]==target:
            print(i,j)
# Out:
# 0 7
# 1 6
# 2 5
# 3 4

# %%
#1464.Maximum product of two elements in an array
